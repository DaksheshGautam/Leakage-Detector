# %%
import pandas as pd
import numpy as np

# %%
import importlib
import leakguard
importlib.reload(leakguard)
# Out:
# <module 'leakguard' from 'd:\\code\\Leakage Detector\\leakguard.py'>

# %%
df = pd.read_csv("leakguard_synthetic_full.csv")
df.head()
# Out:
#    user_id session_id  user_age            timestamp  noise_feature  \
# 0       84       84_5        23  2024-03-17 05:00:00       0.479787
# 1      198      198_5        43  2024-03-25 05:00:00       0.953002
# 2      123      123_0        44  2024-03-06 00:00:00      -0.528978
# 3       75       75_7        38  2024-01-11 07:00:00      -0.131257
# 4      174      174_0        52  2024-03-05 00:00:00       1.232921
#
#    proxy_feature  target
# 0      -0.008694       0
# 1       0.953785       1
# 2      -0.052828       0
# 3       1.003843       1
# 4       0.016850       0

# %%
leakguard.run_leakguard(file_path="leakguard_synthetic_full.csv",target_column="target")
# Out:
# 🛡️ LeakGuard Report (v0.4)
# ...
# Dataset shape: (1636, 7)
#
# ⚠️ Identifier columns detected
# Severity: MEDIUM
# Columns with near-unique values allow row memorization.
# Evidence:
#   • session_id
# Recommended actions:
#   → Drop identifier columns before training
#   → Keep only if needed for joins
# --------------------------------------------------
# ℹ️ Duplicate rows detected
# Severity: LOW
# Duplicate rows can artificially inflate model performance if they appear in both train and test sets.
# Evidence:
#   • 36 rows
# Recommended actions:
#   → Remove duplicate rows
#   → Check data collection pipeline
# --------------------------------------------------
# 🚨 Group leakage risk detected
# Severity: HIGH
# Columns were found that group data points (e.g., user_id, session_id). This can cause leakage if groups are split across train/test sets.
# Evidence:
#   • Grouping column 'user_id': High target consistency (avg. purity: 1.00); Constant entity features: user_age
# ...
