# %%
import pandas as pd
import numpy as np
import importlib
import leakguard

importlib.reload(leakguard)

# %%
df = pd.read_csv("leakguard_synthetic_full.csv")
df.head()
# Out:
#   user_id session_id            timestamp  user_age proxy_feature  target
# 0  user_1  session_1  2023-01-01 12:00:00        30             A       0
# 1  user_1  session_2  2023-01-01 12:05:00        30             B       0
# 2  user_2  session_3  2023-01-02 10:00:00        25             A       1
# 3  user_2  session_4  2023-01-02 10:05:00        25             C       1
# 4  user_3  session_5  2023-01-03 14:00:00        40             B       0

# %%
leakguard.run_leakguard(
    file_path="leakguard_synthetic_full.csv",
    target_column="target",
    show_export_button=True,
    export_button_path="leakguard_report.json"
)
# Out:
# LeakGuard Report (v0.7.0)
# ==================================================
# Dataset shape: (60, 6)
#
# MEDIUM Identifier columns detected
# Severity: MEDIUM
# Columns with near-unique values allow row memorization.
# Evidence:
#   • session_id
#   • timestamp
# Recommended actions:
#   -> Drop identifier columns before training
#   -> Keep only if needed for joins
# --------------------------------------------------
# HIGH Group leakage risk detected
# Severity: HIGH
# Columns were found that group data points (e.g., user_id, session_id). This can cause leakage if groups are split across train/test sets.
# Evidence:
#   • Grouping column 'user_id': High target consistency (avg. purity: 1.00); Constant entity features: user_age
#   • Grouping column 'user_age': High target consistency (avg. purity: 1.00); Constant entity features: user_id
# Recommended actions:
#   -> Use GroupKFold or a similar group-aware splitting strategy, using the identified grouping column(s).
#   -> Ensure that all data for a given group ID is in the same split (train or test).
# --------------------------------------------------
# MEDIUM High feature importance detected
# Severity: MEDIUM
# A simple model found these features to be overwhelmingly predictive, suggesting potential leakage.
# Evidence:
#   • user_age
# Recommended actions:
#   -> Verify if these features are available at prediction time
#   -> Check for target leakage
# --------------------------------------------------
# HIGH Temporal leakage risk
# Severity: HIGH
# Data exhibits strong time-dependence. Random splits will cause future-to-past leakage.
# Evidence:
#   • Temporal Leakage Risk in 'timestamp': Moderate Target Autocorrelation (0.12), High Timestamp Uniqueness. Data appears to be a time-series; use TimeSeriesSplit.
# Recommended actions:
#   -> Use TimeSeriesSplit for validation
#   -> Do not use random K-Fold or train_test_split
# --------------------------------------------------
# End of Report.
#
#
# Advisory
# ==================================================
# Leakage Risk Score: 20
# Recommended Splitting Strategy: TimeSeriesSplit
# • High risk of data leakage. Manual inspection of features is highly recommended.
# ==================================================
